# %%
# Load the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Read the Image and convert to grayscale
image = cv2.imread("1.jpg",1)

image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_gray = cv2.imread("1.jpg",0)

# Use Global thresholding to segment the image
ret,thresh_img1=cv2.threshold(image_gray,86,255,cv2.THRESH_BINARY)

# Display the results
titles=["Gray Image","Threshold Image (Binary)"]
images=[image_gray,thresh_img1]
for i in range(0,9):
    plt.figure(figsize=(10,10))
    plt.subplot(1,2,1)
    plt.title("Original Image")
    plt.imshow(image)
    plt.axis("off")
    plt.subplot(1,2,2)
    plt.title(titles)
    plt.imshow(cv2.cvtColor(images[i],cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-8f58497bf557> in <module>
#      24     plt.subplot(1,2,2)
#      25     plt.title(titles)
# ---> 26     plt.imshow(cv2.cvtColor(images[i],cv2.COLOR_BGR2RGB))
#      27     plt.axis("off")
#      28     plt.show()
#
# IndexError: list index out of range
